# %% [markdown]
# # More Practice With SQL Queries - Lab
#
# ## Introduction
#
# In this lesson, we'll run through some practice questions to refresh our knowledge of SQL Queries!
#
# ## Objectives
#
# You will be able to:
#
# - Practice your SQL knowledge
#
# ## Getting Started
#
# As in previous labs, we'll make use of the `sqlite3` library as well as `pandas`. By combining them, we'll be able to write our queries as python strings, and make sure that the results are always returned as a pandas DataFrame.
#
# We'll start by loading both libraries and connecting to the database we'll be using for this lab, `data.sqlite`. You may remember this database from a previous lab. As a refresher, here's the ERD diagram for this database:
#
# <img src='images/Database-Schema.png'>
#
# In the cell below:
#
# * Import the necessary libraries `pandas` and `sqlite3`
# * Establish a connection to the database `data.sqlite`
# * Get the `cursor` from the connection and store it in the variable `c`.

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Basic Queries
#
# Now, let's review basic SQL queries. In the cell below:
#
# * Write a query that gets the first name, last name, phone number, address, and credit limit for all customers in California with a credit limit greater than 25000.00.

# %%
c.execute("""select customerName, contactFirstName, contactLastName,
                    phone, addressLine1, addressLine2, city,
                    creditLimit
                    from customers
                    where creditLimit>25000;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#                           customerName contactFirstName contactLastName  \
# 0                   Signal Gift Stores             Jean            King
# 1           Australian Collectors, Co.            Peter        Ferguson
# 2                    La Rochelle Gifts          Janine          Labrune
# 3                   Baane Mini Imports           Jonas       Bergulfsen
# 4         Mini Gifts Distributors Ltd.            Susan          Nelson
# 5                 Blauer See Auto, Co.           Roland          Keitel
# 6                      Mini Wheels Co.            Julie          Murphy
# 7                    Land of Toys Inc.             Kwai             Lee
# 8               Euro+ Shopping Channel           Diego           Freyre
# 9             Volvo Model Replicas, Co       Christina         Berglund
# 10            Danish Wholesale Imports           Jytte         Petersen
# 11              Saveley & Henriot, Co.            Mary          Saveley
# 12             Dragon Souveniers, Ltd.             Eric       Natividad
# 13                  Muscle Machine Inc             Jeff           Young
# 14               Diecast Classics Inc.           Kelvin           Leong
# 15                Technics Stores Inc.             Juri       Hashimoto
# 16                    Handji Gifts& Co            Wendy       Victorino
# 17                        Herkku Gifts           Veysel          Oeztan
# 18            Daedalus Designs Imports         Martine            Rancé
# 19           La Corne D'abondance, Co.            Marie        Bertrand
# 20          Cambridge Collectables Co.            Jerry           Tseng
# 21                     Gift Depot Inc.            Julie            King
# 22                Osaka Souveniers Co.             Mory         Kentary
# 23                     Vitachrome Inc.          Michael           Frick
# 24                Toys of Finland, Co.            Matti       Karttunen
# 25                      AV Stores, Co.           Rachel        Ashworth
# 26             Clover Collections, Co.             Dean         Cassidy
# 27               UK Collectables, Ltd.        Elizabeth           Devon
# 28      Canadian Gift Exchange Network           Yoshi           Tamuri
# 29            Online Mini Collectables           Miguel         Barajas
# ..                                 ...              ...             ...
# 64                  Reims Collectables            Paul          Henriot
# 65                     GiftsForHim.com            Wales       MacKinlay
# 66                   Gifts4AllAges.com             Juri         Yoshido
# 67        Online Diecast Creations Co.          Dorothy           Young
# 68          Collectables For Less Inc.            Allen          Nelson
# 69               Salzburg Collectables           Georg            Pipps
# 70                     Cruz & Sons Co.           Arnold            Cruz
# 71                 L'ordine Souveniers        Maurizio           Moroni
# 72             Tokyo Collectables, Ltd            Akiko       Shimamura
# 73                   Auto Canal+ Petit        Dominique         Perrier
# 74       Extreme Desk Decorations, Ltd            Sarah           McRoy
# 75  Bavarian Collectables Imports, Co.          Michael     Donnermeyer
# 76                Classic Legends Inc.            Maria       Hernandez
# 77                    Gift Ideas Corp.              Dan           Lewis
# 78             Scandinavian Gift Ideas           Martha         Larsson
# 79           The Sharp Gifts Warehouse              Sue           Frick
# 80                     Mini Auto Werke          Roland           Mendel
# 81                    Super Scale Inc.           Leslie          Murphy
# 82                     Microscale Inc.               Yu            Choi
# 83          Corrida Auto Replicas, Ltd          Martín           Sommer
# 84                    FunGiftIdeas.com          Violeta         Benitez
# 85        Australian Collectables, Ltd             Sean        Clenahan
# 86                  Frau da Collezione           Franco         Ricotti
# 87         West Coast Collectables Co.            Steve        Thompson
# 88          Iberia Gift Imports, Corp.      José Pedro             Roel
# 89        Motor Mint Distributors Inc.             Rosa         Salazar
# 90            Signal Collectibles Ltd.              Sue          Taylor
# 91      Double Decker Gift Stores, Ltd          Thomas            Smith
# 92                Diecast Collectables          Valarie          Franco
# 93                   Kelly's Gift Shop             Tony         Snowden
#
#                  phone                  addressLine1  \
# 0           7025551838               8489 Strong St.
# 21                              Bridgewater      84300.0
# 22                                  Kita-ku      81200.0
# 23                 Suite 101            NYC      76400.0
# 24                                 Helsinki      96500.0
# 25                               Manchester     136800.0
# 26               Floor No. 4         Dublin      69400.0
# 27                                Liverpool      92700.0
# 28                                Vancouver      90300.0
# 29                               Brickhaven      68700.0
# ..                       ...            ...          ...
# 64                                    Reims      81100.0
# 65                                 Auckland      77700.0
# 66                                   Boston      41900.0
# 67                                   Nashua     114200.0
# 68                               Brickhaven      70700.0
# 69                                 Salzburg      71700.0
# 70     NatWest Center #13-03    Makati City      81500.0
# 71                            Reggio Emilia     121400.0
# 72                                Minato-ku      94400.0
# 73                                    Paris      95000.0
# 74                  Level 11     Wellington      86800.0
# 75                                   Munich      77000.0
# 76                 Suite 750            NYC      67500.0
# 77                                 Glendale      49700.0
# 78                                   Bräcke     116400.0
# 79                                 San Jose      77600.0
# 80                                     Graz      45300.0
# 81                                New Haven      95400.0
# 82                 Suite 200            NYC      39800.0
# 83                                   Madrid     104600.0
# 84                              New Bedford      85800.0
# 85                             Glen Waverly      60300.0
# 86       Alessandro Volta 16          Milan      34800.0
# 87                                  Burbank      55400.0
# 88                                  Sevilla      65700.0
# 89                             Philadelphia      72600.0
# 90                                 Brisbane      60300.0
# 91                                   London      43300.0
# 92                                   Boston      85100.0
# 93                               Auckland       110000.0
#
# [94 rows x 8 columns]

# %%
# For the first query, the boilerplate for getting 
#the query into a dataframe has been provided for you
c.execute(""" """)
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-1.png'>
#
# ## Aggregate Functions and GROUP BY
#
# Next, write a query that get sthe average credit limit per state.

# %%
# If you don't use group by 1, it will have average of all
c.execute("""select state,
                    avg(creditLimit) as 'AVG(creditLimit)'
                    from customers
                    group by 1;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#             state  AVG(creditLimit)
# 0                      61839.726027
# 1              BC      89950.000000
# 2              CA      83854.545455
# 3              CT      57350.000000
# 4        Co. Cork          0.000000
# 5   Isle of Wight      93900.000000
# 6              MA      70755.555556
# 7              NH     114200.000000
# 8              NJ      43000.000000
# 9             NSW     100550.000000
# 10             NV      71800.000000
# 11             NY      89966.666667
# 12          Osaka      81200.000000
# 13             PA      84766.666667
# 14       Pretoria          0.000000
# 15     Queensland      51600.000000
# 16         Québec      48700.000000
# 17          Tokyo      94400.000000
# 18       Victoria      88800.000000

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-2.png'>
#
# ## JOINs
#
# Now, write a query that uses JOIN statements to get the customer name, customer number, order number, status, and quantity ordered. Print only the head of this DataFrame.

# %%
c.execute("""select customerName, customerNumber, orderNumber,
                    status, quantityOrdered
                    from customers
                    join orders using(customerNumber)
                    join orderdetails using(orderNumber);""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#               customerName  customerNumber orderNumber   status  \
# 0           AV Stores, Co.             187       10110  Shipped
# 1             Alpha Cognac             242       10136  Shipped
# 2       Amica Models & Co.             249       10280  Shipped
# 3  Anna's Decorations, Ltd             276       10148  Shipped
# 4        Atelier graphique             103       10123  Shipped
#
#   quantityOrdered
# 0              20
# 1              25
# 2              20
# 3              21
# 4              26

# %% [markdown]
# #### Expected Output
#
# <img src='images/joins.png'>
#
# ## HAVING and ORDER BY
#
# Now, return the customerName, customrerNumber, productName, productCode and total number ordered for any product a customer has bought 10 or more of cumulatively. Sort the rows in descending order by the quantity ordered.
#
# **_Hint_**: For this one, you'll need to make use of HAVING, GROUP BY, and ORDER BY--make sure you get the order of them correct!

# %%
c.execute("""select customerName, customerNumber, productName,
                    productCode, quantityOrdered
                    from customers
                    join orders using(customerNumber)
                    join orderdetails using(orderNumber)
                    join products using(productCode)
                    group by 1
                    having quantityOrdered>10
                    order by quantityOrdered desc;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#                    customerName  customerNumber  \
# 0      Danish Wholesale Imports             145
# 1      Online Mini Collectables             204
# 2      Signal Collectibles Ltd.             487
# 3  Collectable Mini Designs Co.             239
# 4      Corporate Gift Ideas Co.             321
#
#                              productName productCode quantityOrdered
# 0                    1972 Alfa Romeo GTA    S10_4757              50
# 1                      1968 Ford Mustang    S12_1099              50
# 2                   1937 Lincoln Berline    S18_1342              50
# 3                    1972 Alfa Romeo GTA    S10_4757              49
# 4  1969 Harley Davidson Ultimate Chopper    S10_1678              49

# %% [markdown]
# #### Expected Output
#
# <img src='images/having_order.png'>
#
# ## Subqueries
#
# Finally, get the first name, last name, employee number, and office code for employees from an office with less than 5 employees.

# %%
c.execute("""select firstName, lastName, employeeNumber,
                    officeCode
                    from employees
                    where officeCode in
                    (select officeCode
                            from offices
                            join employees
                            using(officeCode)
                            group by 1
                            having count(employeeNumber)<5)
                    ;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#   firstName   lastName employeeNumber officeCode
# 0   William  Patterson           1088          6
# 1     Julie   Firrelli           1188          2
# 2     Steve  Patterson           1216          2
# 3  Foon Yue      Tseng           1286          3
# 4    George     Vanauf           1323          3

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-5.png'>
#
# # Summary
#
# In this lesson, we reviewed all the major concepts and keywords associated with SQL queries!
